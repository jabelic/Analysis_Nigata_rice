# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df_result = pd.read_csv('result.csv', index_col = 0)
print(df_result)
# Out:
#          PC1       PC2    SVM正答率
# 月
# 1   0.940447  0.055019  0.764706
# 2   0.959877  0.036718  0.823529
# 3   0.978775  0.019345  0.823529
# 4   0.981803  0.016482  0.882353
# 5   0.991185  0.008115  0.823529
# 6   0.990960  0.008497  0.764706
# 7   0.993773  0.005820  0.823529
# 8   0.995784  0.003975  0.764706
# 9   0.984918  0.013515  0.764706
# 10  0.984624  0.013821  0.588235
# 11  0.970594  0.025379  0.647059
# 12  0.943081  0.051117  0.764706

# %%
month = [i for i in range(1,13)]
PC1 = df_result['PC1'].values
PC2 = df_result['PC2'].values
SVM_score = df_result['SVM正答率'].values

# %%
plt.plot(month, PC1, label = "PC1")
plt.legend()
plt.show()
plt.plot(month, PC2 ,label = "PC2", color = "green")
plt.legend()
plt.show()

fig = plt.figure()
ax = fig.add_subplot(212)
ax.scatter3D(PC1, PC2 ,month ,label = "data", color = "orange")
plt.legend()
plt.show()

plt.plot(month, SVM_score ,label = "SVM", color = "red")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3258337d2487> in <module>()
#       8 fig = plt.figure()
#       9 ax = fig.add_subplot(212)
# ---> 10 ax.scatter3D(PC1, PC2 ,month ,label = "data", color = "orange")
#      11 plt.legend()
#      12 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'scatter3D'
