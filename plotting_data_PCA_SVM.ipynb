# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df_result = pd.read_csv('result.csv', index_col = 0)
print(df_result)
# Out:
#             PC1       PC2  SVM_score
# month
# 1      0.948290  0.049088   0.529412
# 2      0.841302  0.151448   0.352941
# 3      0.726571  0.266117   0.588235
# 4      0.707992  0.285218   0.705882
# 5      0.718615  0.278711   0.882353
# 6      0.835200  0.163343   0.529412
# 7      0.907491  0.091873   0.588235
# 8      0.902660  0.096692   0.352941
# 9      0.906668  0.092054   0.352941
# 10     0.867753  0.129710   0.235294
# 11     0.953945  0.043966   0.470588
# 12     0.965803  0.031950   0.588235

# %%
month = [i for i in range(1,13)]
PC1 = df_result['PC1'].values
PC2 = df_result['PC2'].values
SVM_score = df_result['SVM_score'].values

# %%
fig = plt.figure()
ax = fig.add_subplot(212, projection='3d')
ax.scatter3D(PC1, PC2 ,month )
#plt.legend()
plt.show()

plt.plot(month, PC1, label = "PC1")
plt.legend()
plt.show()
plt.plot(month, PC2 ,label = "PC2", color = "green")
plt.legend()
plt.show()

plt.plot(month, SVM_score ,label = "SVM", color = "red")
plt.legend()
plt.show()
